# %%
import pandas as pd
boys=pd.DataFrame({'Michael':['money','more money'],'Aubrey':['food','more']}, index=['Person 1', 'Person 2'])

# %%
pd.Series([1,2,3,4,5])
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %%
boys
# Out:
#              Michael Aubrey
# Person 1       money   food
# Person 2  more money   more

# %%
boys.iloc[0]
# Out:
# Michael    money
# Aubrey      food
# Name: Person 1, dtype: object

# %%
boys.loc[:, 'Aubrey']
# Out:
# Person 1    food
# Person 2    more
# Name: Aubrey, dtype: object

# %%
boys
# Out:
#              Michael Aubrey
# Person 1       money   food
# Person 2  more money   more

# %%
boys.Michael
# Out:
# Person 1         money
# Person 2    more money
# Name: Michael, dtype: object

# %%
boys.Michael=='money'
# Out:
# Person 1     True
# Person 2    False
# Name: Michael, dtype: bool

# %%
boys.loc[(boys.Michael=='money') & (boys.Aubrey=='food')]
# Out:
#          Michael Aubrey
# Person 1   money   food

# %%
boys.loc[(boys.Michael=='money') | (boys.Aubrey=='food')]
# Out:
#          Michael Aubrey
# Person 1   money   food

# %%
boys.loc[boys.Michael.isin(['money', 'more money'])]
# Out:
#              Michael Aubrey
# Person 1       money   food
# Person 2  more money   more

# %%
boys.loc[boys.Michael.notnull()]
# Out:
#              Michael Aubrey
# Person 1       money   food
# Person 2  more money   more

# %%
import pandas as pd

reviews = pd.read_csv("/Users/pesseym/Documents/Datasets/wine_data.csv", index_col=0)
pd.set_option("display.max_rows", 5)

reviews
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.head()
# Out:
#     country                                        description  \
# 0     Italy  Aromas include tropical fruit, broom, brimston...
# 1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2        US  Tart and snappy, the flavors of lime flesh and...
# 3        US  Pineapple rind, lemon pith and orange blossom ...
# 4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# 0                 Etna                NaN       Kerin O’Keefe
# ...

# %%
reviews_points_mean=reviews.points.mean()
reviews.points.map(lambda p : p - reviews_points_mean)
# Out:
# 0        -1.447138
# 1        -1.447138
#             ...
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
def remean_points(row):
    row.points = row.points - reviews_points_mean
    return row

reviews.apply(remean_points, axis='columns')
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation    points  price           province  \
# 0                        Vulkà Bianco -1.447138    NaN  Sicily & Sardinia
# 1                            Avidagos -1.447138   15.0              Douro
# ...                               ...       ...    ...                ...
# 129969                            NaN  1.552862   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline  1.552862   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews_points_mean=reviews.points.mean()
reviews.points-reviews_points_mean
# Out:
# 0        -1.447138
# 1        -1.447138
#             ...
# 129969    1.552862
# 129970    1.552862
# Name: points, Length: 129971, dtype: float64

# %%
reviews.country + '-' + reviews.region_1
# Out:
# 0            Italy-Etna
# 1                   NaN
#               ...
# 129969    France-Alsace
# 129970    France-Alsace
# Length: 129971, dtype: object

# %%
bargain_wine = reviews['title'].loc[(reviews.points/reviews.price).idxmax()]
bargain_wine
# Out:
# 'Bandit NV Merlot (California)'

# %%
n_trop = reviews.description.map(lambda x : 'tropical' in x).sum()
n_fruity = reviews.description.map(lambda x : 'fruity' in x).sum()

descriptor_counts = pd.Series([n_trop, n_fruity], index=['tropical', 'fruity'])
descriptor_counts
# Out:
# tropical    3607
# fruity      9090
# dtype: int64

# %%
def ratings(row):
    if row.country=='Canada':
        return 3
    elif row.points>=95:
        return 3
    elif row.points>=85 & row.points<=95:
        return 2
    else:
        return 1
star_ratings=reviews.apply(ratings, axis=1)
star_ratings
# Out:
# 0         2
# 1         2
#          ..
# 129969    2
# 129970    2
# Length: 129971, dtype: int64

# %%
reviews.groupby('points').points.count()
# Out:
# points
# 80     397
# 81     692
#       ...
# 99      33
# 100     19
# Name: points, Length: 21, dtype: int64

# %%
reviews.groupby('points').points.count()
# Out:
# points
# 80     397
# 81     692
#       ...
# 99      33
# 100     19
# Name: points, Length: 21, dtype: int64

# %%
reviews.points.value_counts()
# Out:
# 88     17207
# 87     16933
#        ...
# 99        33
# 100       19
# Name: points, Length: 21, dtype: int64

# %%
reviews.groupby('points').price.min()
# Out:
# points
# 80      5.0
# 81      5.0
#        ...
# 99     44.0
# 100    80.0
# Name: price, Length: 21, dtype: float64

# %%
reviews.groupby('winery').apply(lambda df: df.title.iloc[0])
# Out:
# winery
# 1+1=3                          1+1=3 NV Rosé Sparkling (Cava)
# 10 Knots                 10 Knots 2010 Viognier (Paso Robles)
#                                   ...
# àMaurice    àMaurice 2013 Fred Estate Syrah (Walla Walla V...
# Štoka                         Štoka 2009 Izbrani Teran (Kras)
# Length: 16757, dtype: object

# %%
reviews.groupby(['country', 'province']).apply(lambda df: df.loc[df.points.idxmax()])
# Out:
#                               country  \
# country   province
# Argentina Mendoza Province  Argentina
#           Other             Argentina
# ...                               ...
# Uruguay   San Jose            Uruguay
#           Uruguay             Uruguay
#
#                                                                   description  \
# country   province
# Argentina Mendoza Province  If the color doesn't tell the full story, the ...
#           Other             Take note, this could be the best wine Colomé ...
# ...                                                                       ...
# Uruguay   San Jose          Baked, sweet, heavy aromas turn earthy with ti...
#           Uruguay           Cherry and berry aromas are ripe, healthy and ...
#
#                                           designation  points  price  \
# country   province
# Argentina Mendoza Province           Nicasia Vineyard      97  120.0
# ...

# %%
reviews.groupby(['country']).price.agg([len, min, max])
# Out:
#             len   min    max
# country
# Argentina  3800   4.0  230.0
# Armenia       2  14.0   15.0
# ...         ...   ...    ...
# Ukraine      14   6.0   13.0
# Uruguay     109  10.0  130.0
#
# [43 rows x 3 columns]

# %%
countries_reviewed = reviews.groupby(['country', 'province']).description.agg([len])
countries_reviewed
# Out:
#                              len
# country   province
# Argentina Mendoza Province  3264
#           Other              536
# ...                          ...
# Uruguay   San Jose             3
#           Uruguay             24
#
# [425 rows x 1 columns]

# %%
type(countries_reviewed.index)
# Out:
# pandas.core.indexes.multi.MultiIndex

# %%
countries_reviewed.reset_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# ..         ...               ...   ...
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %%
countries_reviewed = countries_reviewed.reset_index()
countries_reviewed.sort_values(by='len')
# Out:
#     country               province    len
# 179  Greece  Muscat of Kefallonian      1
# 192  Greece          Sterea Ellada      1
# ..      ...                    ...    ...
# 415      US             Washington   8639
# 392      US             California  36247
#
# [425 rows x 3 columns]

# %%
countries_reviewed.sort_values(by='len', ascending=False)
# Out:
#     country    province    len
# 392      US  California  36247
# 415      US  Washington   8639
# ..      ...         ...    ...
# 63    Chile     Coelemu      1
# 149  Greece      Beotia      1
#
# [425 rows x 3 columns]

# %%
countries_reviewed.sort_index()
# Out:
#        country          province   len
# 0    Argentina  Mendoza Province  3264
# 1    Argentina             Other   536
# ..         ...               ...   ...
# 423    Uruguay          San Jose     3
# 424    Uruguay           Uruguay    24
#
# [425 rows x 3 columns]

# %%
countries_reviewed.sort_values(by=['country', 'len'])
# Out:
#        country          province   len
# 1    Argentina             Other   536
# 0    Argentina  Mendoza Province  3264
# ..         ...               ...   ...
# 424    Uruguay           Uruguay    24
# 419    Uruguay         Canelones    43
#
# [425 rows x 3 columns]

# %%
best_rating_per_price = reviews.groupby('price')['points'].max().sort_index()

# %%
best_rating_per_price
# Out:
# price
# 4.0       86
# 5.0       87
#           ..
# 2500.0    96
# 3300.0    88
# Name: points, Length: 390, dtype: int64

# %%
price_extremes = reviews.groupby('variety').price.agg([min,max])
price_extremes
# Out:
#               min   max
# variety
# Abouriou     15.0  75.0
# Agiorgitiko  10.0  66.0
# ...           ...   ...
# Çalkarası    19.0  19.0
# Žilavka      15.0  15.0
#
# [707 rows x 2 columns]

# %%
reviews.price.agg([min, max])
# Out:
# min       4.0
# max    3300.0
# Name: price, dtype: float64

# %%
reviews.groupby('variety').price.agg([min, max])
# Out:
#               min   max
# variety
# Abouriou     15.0  75.0
# Agiorgitiko  10.0  66.0
# ...           ...   ...
# Çalkarası    19.0  19.0
# Žilavka      15.0  15.0
#
# [707 rows x 2 columns]

# %%
reviews.groupby(['country', 'variety']).size().sort_values(ascending=False)
# Out:
# country  variety
# US       Pinot Noir            9885
#          Cabernet Sauvignon    7315
#                                ...
# Mexico   Rosado                   1
# Uruguay  White Blend              1
# Length: 1612, dtype: int64

# %%
reviews['price'].dtype
# Out:
# dtype('float64')

# %%
reviews.dtypes
# Out:
# country        object
# description    object
#                 ...
# variety        object
# winery         object
# Length: 13, dtype: object

# %%
reviews.points.astype('float64')
# Out:
# 0         87.0
# 1         87.0
#           ...
# 129969    90.0
# 129970    90.0
# Name: points, Length: 129971, dtype: float64

# %%
reviews.points.dtype
# Out:
# dtype('int64')

# %%
reviews.index.dtype
# Out:
# dtype('int64')

# %%
reviews[pd.isnull(reviews.country)]
# Out:
#        country                                        description  \
# 913        NaN  Amber in color, this wine has aromas of peach ...
# 3131       NaN  Soft, fruity and juicy, this is a pleasant, si...
# ...        ...                                                ...
# 129590     NaN  A blend of 60% Syrah, 30% Cabernet Sauvignon a...
# 129900     NaN  This wine offers a delightful bouquet of black...
#
#            designation  points  price province region_1 region_2  \
# 913     Asureti Valley      87   30.0      NaN      NaN      NaN
# 3131          Partager      83    NaN      NaN      NaN      NaN
# ...                ...     ...    ...      ...      ...      ...
# 129590            Shah      90   30.0      NaN      NaN      NaN
# 129900             NaN      91   32.0      NaN      NaN      NaN
#
#           taster_name taster_twitter_handle  \
# 913     Mike DeSimone        @worldwineguys
# 3131       Roger Voss            @vossroger
# ...

# %%
reviews[pd.notnull(reviews.country)]
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# ...                               ...     ...    ...                ...
# 129969                            NaN      90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# ...

# %%
reviews.region_2.fillna('Unknown')
# Out:
# 0         Unknown
# 1         Unknown
#            ...
# 129969    Unknown
# 129970    Unknown
# Name: region_2, Length: 129971, dtype: object

# %%
reviews.taster_twitter_handle.replace("@kerinokeefe", "@kerino")
# Out:
# 0            @kerino
# 1         @vossroger
#              ...
# 129969    @vossroger
# 129970    @vossroger
# Name: taster_twitter_handle, Length: 129971, dtype: object

# %%
import numpy as np
reviews.region_2.replace(np.nan, "hm")
# Out:
# 0         hm
# 1         hm
#           ..
# 129969    hm
# 129970    hm
# Name: region_2, Length: 129971, dtype: object

# %%
missing_price_reviews = reviews[reviews.price.isnull()]
len(missing_price_reviews)
# Out:
# 8996

# %%
reviews.region_1.fillna('Unknown').value_counts().sort_values(ascending=False)
# Out:
# Unknown        21247
# Napa Valley     4480
#                ...
# Geelong            1
# Paestum            1
# Name: region_1, Length: 1230, dtype: int64

# %%
reviews.rename(columns={'points':'score'})
# Out:
#          country                                        description  \
# 0          Italy  Aromas include tropical fruit, broom, brimston...
# 1       Portugal  This is ripe and fruity, a wine that is smooth...
# ...          ...                                                ...
# 129969    France  A dry style of Pinot Gris, this is crisp with ...
# 129970    France  Big, rich and off-dry, this is powered by inte...
#
#                           designation  score  price           province  \
# 0                        Vulkà Bianco     87    NaN  Sicily & Sardinia
# 1                            Avidagos     87   15.0              Douro
# ...                               ...    ...    ...                ...
# 129969                            NaN     90   32.0             Alsace
# 129970  Lieu-dit Harth Cuvée Caroline     90   21.0             Alsace
#
#        region_1 region_2    taster_name taster_twitter_handle  \
# 0          Etna      NaN  Kerin O’Keefe          @kerinokeefe
# ...

# %%
reviews.rename(index={0: 'firstEntry', 1: 'secondEntry'})
# Out:
#               country                                        description  \
# firstEntry      Italy  Aromas include tropical fruit, broom, brimston...
# secondEntry  Portugal  This is ripe and fruity, a wine that is smooth...
# ...               ...                                                ...
# 129969         France  A dry style of Pinot Gris, this is crisp with ...
# 129970         France  Big, rich and off-dry, this is powered by inte...
#
#                                designation  points  price           province  \
# firstEntry                    Vulkà Bianco      87    NaN  Sicily & Sardinia
# secondEntry                       Avidagos      87   15.0              Douro
# ...                                    ...     ...    ...                ...
# 129969                                 NaN      90   32.0             Alsace
# 129970       Lieu-dit Harth Cuvée Caroline      90   21.0             Alsace
#
# ...

# %%
reviews.set_index('price')
# Out:
#         country                                        description  \
# price
# NaN       Italy  Aromas include tropical fruit, broom, brimston...
# 15.0   Portugal  This is ripe and fruity, a wine that is smooth...
# ...         ...                                                ...
# 32.0     France  A dry style of Pinot Gris, this is crisp with ...
# 21.0     France  Big, rich and off-dry, this is powered by inte...
#
#                          designation  points           province region_1  \
# price
# NaN                     Vulkà Bianco      87  Sicily & Sardinia     Etna
# 15.0                        Avidagos      87              Douro      NaN
# ...                              ...     ...                ...      ...
# 32.0                             NaN      90             Alsace   Alsace
# 21.0   Lieu-dit Harth Cuvée Caroline      90             Alsace   Alsace
#
#       region_2    taster_name taster_twitter_handle  \
# price
# ...

# %%
missing_values_count=reviews.isnull().sum()

# %%
missing_values_count[0:5]
# Out:
# country           63
# description        0
# designation    37465
# points             0
# price           8996
# dtype: int64

# %%
missing_values_count.sum()
# Out:
# 204752

# %%
import numpy as np
total_entries=np.product(reviews.shape)
total_missing=missing_values_count.sum()

# %%
percentage_missing=(total_missing/total_entries)*100
percentage_missing
# Out:
# 12.118206250743508

# %%
import pandas as pd
import numpy as np
nfl_data=pd.read_csv('/Users/pesseym/Documents/Datasets/nfl_data_2009-2017.csv')
nfl_data.head()
# Out:
# /var/folders/nh/vmh6pw851f9_43gsjqvwttj00000gn/T/ipykernel_891/2208569000.py:3: DtypeWarning: Columns (25,51) have mixed types. Specify dtype option on import or set low_memory=False.
#   nfl_data=pd.read_csv('/Users/pesseym/Documents/Datasets/nfl_data_2009-2017.csv')
#          Date      GameID  Drive  qtr  down   time  TimeUnder  TimeSecs  \
# 0  2009-09-10  2009091000      1    1   NaN  15:00         15    3600.0
# 1  2009-09-10  2009091000      1    1   1.0  14:53         15    3593.0
# 2  2009-09-10  2009091000      1    1   2.0  14:16         15    3556.0
# 3  2009-09-10  2009091000      1    1   3.0  13:35         14    3515.0
# 4  2009-09-10  2009091000      1    1   4.0  13:27         14    3507.0
#
#    PlayTimeDiff SideofField  ...    yacEPA  Home_WP_pre  Away_WP_pre  \
# 0           0.0         TEN  ...       NaN     0.485675     0.514325
# 1           7.0         PIT  ...  1.146076     0.546433     0.453567
# ...

# %%
missing_values_count=nfl_data.isnull().sum()
# missing_values_count
total_entries=np.product(nfl_data.shape)
total_missing=missing_values_count.sum()
percentage_missing=(total_missing/total_entries)*100
percentage_missing
# Out:
# 24.87214126835169

# %%
mean_down=nfl_data.down.mean()
nfl_data.down.fillna(mean_down)
# Out:
# 0         2.002476
# 1         1.000000
#             ...
# 407686    1.000000
# 407687    2.002476
# Name: down, Length: 407688, dtype: float64

# %%
nfl_data.dropna()
# Out:
# Empty DataFrame
# ...

# %%
columns_na_dropped=nfl_data.dropna(axis=1)
columns_na_dropped.head()
# Out:
#          Date      GameID  Drive  qtr  TimeUnder  ydstogo  ydsnet  \
# 0  2009-09-10  2009091000      1    1         15        0       0
# 1  2009-09-10  2009091000      1    1         15       10       5
# 2  2009-09-10  2009091000      1    1         15        5       2
# 3  2009-09-10  2009091000      1    1         14        8       2
# 4  2009-09-10  2009091000      1    1         14        8       2
#
#    PlayAttempted  Yards.Gained  sp  ...  Timeout_Indicator  Timeout_Team  \
# 0              1            39   0  ...                  0          None
# 1              1             5   0  ...                  0          None
# 2              1            -3   0  ...                  0          None
# 3              1             0   0  ...                  0          None
# 4              1             0   0  ...                  0          None
#
#    posteam_timeouts_pre HomeTimeouts_Remaining_Pre AwayTimeouts_Remaining_Pre  \
# ...

# %%
print("Columns in original dataset: %d \n" % nfl_data.shape[1])
print("Columns with na's dropped: %d" % columns_na_dropped.shape[1])
# Out:
# Columns in original dataset: 102
#
# Columns with na's dropped: 41

# %%
subset_nfl_data = nfl_data.loc[:, 'EPA':'Season'].head()
subset_nfl_data
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474       NaN       NaN     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760       NaN       NaN     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796       NaN       NaN     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758       NaN       NaN    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295       NaN       NaN    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712       NaN       NaN    2009

# %%
subset_nfl_data.fillna(0)
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474  0.000000  0.000000     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760  0.000000  0.000000     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796  0.000000  0.000000     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758  0.000000  0.000000    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295  0.000000  0.000000    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712  0.000000  0.000000    2009

# %%
subset_nfl_data.fillna(method='bfill', axis=0).fillna(0)
# Out:
#         EPA    airEPA    yacEPA  Home_WP_pre  Away_WP_pre  Home_WP_post  \
# 0  2.014474 -1.068169  1.146076     0.485675     0.514325      0.546433
# 1  0.077907 -1.068169  1.146076     0.546433     0.453567      0.551088
# 2 -1.402760  3.318841 -5.031425     0.551088     0.448912      0.510793
# 3 -1.712583  3.318841 -5.031425     0.510793     0.489207      0.461217
# 4  2.097796  0.000000  0.000000     0.461217     0.538783      0.558929
#
#    Away_WP_post  Win_Prob       WPA    airWPA    yacWPA  Season
# 0      0.453567  0.485675  0.060758 -0.032244  0.036899    2009
# 1      0.448912  0.546433  0.004655 -0.032244  0.036899    2009
# 2      0.489207  0.551088 -0.040295  0.106663 -0.156239    2009
# 3      0.538783  0.510793 -0.049576  0.106663 -0.156239    2009
# 4      0.441071  0.461217  0.097712  0.000000  0.000000    2009

# %%
sf_permits=pd.read_csv('/Users/pesseym/Documents/Datasets/Building_Permits.csv')
sf_permits.head()
# Out:
# /var/folders/nh/vmh6pw851f9_43gsjqvwttj00000gn/T/ipykernel_4600/4280187729.py:1: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   sf_permits=pd.read_csv('/Users/pesseym/Documents/Datasets/Building_Permits.csv')
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# ...

# %%
sf_permits[['Street Number Suffix','Zipcode']].fillna('Unknown')
# Out:
#        Street Number Suffix  Zipcode
# 0                   Unknown  94102.0
# 1                   Unknown  94102.0
# ...                     ...      ...
# 198898              Unknown  Unknown
# 198899              Unknown  Unknown
#
# [198900 rows x 2 columns]

# %%
sf_permits_with_na_dropped=sf_permits.dropna(axis=1)
dropped_columns = sf_permits.shape[1]-sf_permits_with_na_dropped.shape[1]

# %%
dropped_columns
# Out:
# 31

# %%
sf_permits.fillna(method='bfill').fillna(0)
# Out:
#        Permit Number  Permit Type  Permit Type Definition  \
# 0       201505065519            4            sign - erect
# 1       201604195146            4            sign - erect
# ...              ...          ...                     ...
# 198898       M863747            8  otc alterations permit
# 198899       M864287            8  otc alterations permit
#
#        Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0                05/06/2015  0326  023            140                    A
# 1                04/19/2016  0306  007            440                    A
# ...                     ...   ...  ...            ...                  ...
# 198898           12/06/2017  0298  029            795                    0
# 198899           12/07/2017  0160  006            838                    0
#
#        Street Name Street Suffix  ...  Existing Construction Type  \
# 0            Ellis            St  ...                         3.0
# ...

# %%
import pandas as pd
import numpy as np

# for Box-Cox Transformation
from scipy import stats

# for min_max scaling
from mlxtend.preprocessing import minmax_scaling

# plotting modules
import seaborn as sns
import matplotlib.pyplot as plt

# set seed for reproducibility
np.random.seed(0)

# %%
# generate 1000 data points randomly drawn from an exponential distribution
original_data = np.random.exponential(size=1000)

# mix-max scale the data between 0 and 1
scaled_data = minmax_scaling(original_data, columns=[0])

# plot both together to compare
fig, ax = plt.subplots(1, 2, figsize=(15, 3))
sns.histplot(original_data, ax=ax[0], kde=True, legend=False)
ax[0].set_title("Original Data")
sns.histplot(scaled_data, ax=ax[1], kde=True, legend=False)
ax[1].set_title("Scaled data")
plt.show()

# %%
# normalize the exponential data with boxcox
normalized_data = stats.boxcox(original_data)

# plot both together to compare
fig, ax=plt.subplots(1, 2, figsize=(15, 3))
sns.histplot(original_data, ax=ax[0], kde=True, legend=False)
ax[0].set_title("Original Data")
sns.histplot(normalized_data[0], ax=ax[1], kde=True, legend=False)
ax[1].set_title("Normalized data")
plt.show()

# %%
reviews=pd.read_csv('/Users/pesseym/Documents/Datasets/wine_data.csv')
reviews.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
original_points=reviews.points
original_points
# Out:
# 0         87
# 1         87
# 2         87
# 3         87
# 4         87
#           ..
# 129966    90
# 129967    90
# 129968    90
# 129969    90
# 129970    90
# Name: points, Length: 129971, dtype: int64

# %%
from mlxtend.preprocessing import minmax_scaling
scaled_points=minmax_scaling(original_points, columns=['points'])
sns.histplot(scaled_points, kde=True)
plt.show()

# %%
sns.histplot(original_points, kde=True)
plt.show()

# %%
from scipy import stats
normalised_points=pd.Series(stats.boxcox(original_points)[0])
sns.histplot(normalised_points, kde=True)
# Out:
# <Axes: ylabel='Count'>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import datetime

# read in our data
sf_permits = pd.read_csv("/Users/pesseym/Documents/Datasets/Building_Permits.csv")

# set seed for reproducibility
np.random.seed(0)
# Out:
# /var/folders/nh/vmh6pw851f9_43gsjqvwttj00000gn/T/ipykernel_921/668270623.py:7: DtypeWarning: Columns (22,32) have mixed types. Specify dtype option on import or set low_memory=False.
#   sf_permits = pd.read_csv("/Users/pesseym/Documents/Datasets/Building_Permits.csv")

# %%
sf_permits.head()
# Out:
#   Permit Number  Permit Type            Permit Type Definition  \
# 0  201505065519            4                      sign - erect
# 1  201604195146            4                      sign - erect
# 2  201605278609            3  additions alterations or repairs
# 3  201611072166            8            otc alterations permit
# 4  201611283529            6                       demolitions
#
#   Permit Creation Date Block  Lot  Street Number Street Number Suffix  \
# 0           05/06/2015  0326  023            140                  NaN
# 1           04/19/2016  0306  007            440                  NaN
# 2           05/27/2016  0595  203           1647                  NaN
# 3           11/07/2016  0156  011           1230                  NaN
# 4           11/28/2016  0342  001            950                  NaN
#
#   Street Name Street Suffix  ...  Existing Construction Type  \
# 0       Ellis            St  ...                         3.0
# ...

# %%
sf_permits['Permit Creation Date'].head()
# Out:
# 0    05/06/2015
# 1    04/19/2016
# 2    05/27/2016
# 3    11/07/2016
# 4    11/28/2016
# Name: Permit Creation Date, dtype: object

# %%
sf_permits['Permit Creation Date'].dtype
# Out:
# dtype('O')

# %%
sf_permits['parsed_date'] = pd.to_datetime(sf_permits['Permit Creation Date'], format="%m/%d/%Y")

# %%
sf_permits['parsed_date'].head()
# Out:
# 0   2015-05-06
# 1   2016-04-19
# 2   2016-05-27
# 3   2016-11-07
# 4   2016-11-28
# Name: parsed_date, dtype: datetime64[ns]

# %%
sf_permits['date_parsed'] = pd.to_datetime(sf_permits['Filed Date'], infer_datetime_format=True)

# %%
sf_permits['date_parsed']
# Out:
# 0        2015-05-06
# 1        2016-04-19
# 2        2016-05-27
# 3        2016-11-07
# 4        2016-11-28
#             ...
# 198895   2017-12-05
# 198896   2017-12-05
# 198897   2017-12-06
# 198898   2017-12-06
# 198899   2017-12-07
# Name: date_parsed, Length: 198900, dtype: datetime64[ns]

# %%
day_of_month_sf_permits = sf_permits['date_parsed'].dt.day
day_of_month_sf_permits.head()
# Out:
# 0     6
# 1    19
# 2    27
# 3     7
# 4    28
# Name: date_parsed, dtype: int64

# %%
sf_permits['p_date']=pd.to_datetime(sf_permits['Issued Date'], format='%m/%d/%Y')

# %%
sf_permits['p_date']
# Out:
# 0        2015-11-09
# 1        2017-08-03
# 2               NaT
# 3        2017-07-18
# 4        2017-12-01
#             ...
# 198895   2017-12-05
# 198896   2017-12-06
# 198897   2017-12-06
# 198898   2017-12-06
# 198899   2017-12-07
# Name: p_date, Length: 198900, dtype: datetime64[ns]

# %%
month_sf_permits=sf_permits['p_date'].dt.day
month_sf_permits
# Out:
# 0          9.0
# 1          3.0
# 2          NaN
# 3         18.0
# 4          1.0
#           ...
# 198895     5.0
# 198896     6.0
# 198897     6.0
# 198898     6.0
# 198899     7.0
# Name: p_date, Length: 198900, dtype: float64

# %%
month_sf_permits=month_sf_permits.dropna()
sns.distplot(month_sf_permits, kde=False, bins=31)
# Out:
# /var/folders/nh/vmh6pw851f9_43gsjqvwttj00000gn/T/ipykernel_921/1004686791.py:2: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(month_sf_permits, kde=False, bins=31)
# <Axes: xlabel='p_date'>

# %%
# modules we'll use
import pandas as pd
import numpy as np

# helpful character encoding module
import charset_normalizer

# set seed for reproducibility
np.random.seed(0)

# %%
# start with a string
before = "This is the euro symbol: €"

# check to see what datatype it is
type(before)
# Out:
# str

# %%
# encode it to a different encoding, replacing characters that raise errors
after = before.encode("utf-8", errors="replace")

# check the type
type(after)
# Out:
# bytes

# %%
after
# Out:
# b'This is the euro symbol: ?'

# %%
# convert it back to utf-8
print(after.decode("utf-8"))
# Out:
# This is the euro symbol: €

# %%
# look at the first ten thousand bytes to guess the character encoding
with open("/Users/pesseym/Documents/Datasets/wine_data.csv", 'rb') as rawdata:
    result = charset_normalizer.detect(rawdata.read(10000))

# check what the character encoding might be
print(result)
# Out:
# {'encoding': 'utf-8', 'language': 'English', 'confidence': 0.9968}

# %%
reviews=pd.read_csv('/Users/pesseym/Documents/Datasets/wine_data.csv')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 reviews=pd.read_csv('/Users/pesseym/Documents/Datasets/wine_data.csv')
#
# NameError: name 'pd' is not defined

# %%
reviews
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
reviews.price=reviews.price.fillna(method='bfill')

# %%
reviews
# Out:
#         Unnamed: 0   country  \
# 0                0     Italy
# 1                1  Portugal
# 2                2        US
# 3                3        US
# 4                4        US
# ...            ...       ...
# 129966      129966   Germany
# 129967      129967        US
# 129968      129968    France
# 129969      129969    France
# 129970      129970    France
#
#                                               description  \
# 0       Aromas include tropical fruit, broom, brimston...
# 1       This is ripe and fruity, a wine that is smooth...
# 2       Tart and snappy, the flavors of lime flesh and...
# 3       Pineapple rind, lemon pith and orange blossom ...
# 4       Much like the regular bottling from 2012, this...
# ...                                                   ...
# 129966  Notes of honeysuckle and cantaloupe sweeten th...
# 129967  Citation is given as much as a decade of bottl...
# 129968  Well-drained gravel soil gives this wine its c...
# ...

# %%
# modules we'll use
import pandas as pd
import numpy as np

# helpful modules
import fuzzywuzzy
from fuzzywuzzy import process
import charset_normalizer

# read in all our data
reviews = pd.read_csv("/Users/pesseym/Documents/Datasets/wine_data.csv")

# set seed for reproducibility
np.random.seed(0)

# %%
reviews.head()
# Out:
#    Unnamed: 0   country                                        description  \
# 0           0     Italy  Aromas include tropical fruit, broom, brimston...
# 1           1  Portugal  This is ripe and fruity, a wine that is smooth...
# 2           2        US  Tart and snappy, the flavors of lime flesh and...
# 3           3        US  Pineapple rind, lemon pith and orange blossom ...
# 4           4        US  Much like the regular bottling from 2012, this...
#
#                           designation  points  price           province  \
# 0                        Vulkà Bianco      87    NaN  Sicily & Sardinia
# 1                            Avidagos      87   15.0              Douro
# 2                                 NaN      87   14.0             Oregon
# 3                Reserve Late Harvest      87   13.0           Michigan
# 4  Vintner's Reserve Wild Child Block      87   65.0             Oregon
#
#               region_1           region_2         taster_name  \
# ...

# %%
countries=reviews.country.dropna().unique()
countries
# Out:
# array(['Italy', 'Portugal', 'US', 'Spain', 'France', 'Germany',
#        'Argentina', 'Chile', 'Australia', 'Austria', 'South Africa',
#        'New Zealand', 'Israel', 'Hungary', 'Greece', 'Romania', 'Mexico',
#        'Canada', 'Turkey', 'Czech Republic', 'Slovenia', 'Luxembourg',
#        'Croatia', 'Georgia', 'Uruguay', 'England', 'Lebanon', 'Serbia',
#        'Brazil', 'Moldova', 'Morocco', 'Peru', 'India', 'Bulgaria',
#        'Cyprus', 'Armenia', 'Switzerland', 'Bosnia and Herzegovina',
#        'Ukraine', 'Slovakia', 'Macedonia', 'China', 'Egypt'], dtype=object)

# %%
countries.sort()
countries
# Out:
# array(['Argentina', 'Armenia', 'Australia', 'Austria',
#        'Bosnia and Herzegovina', 'Brazil', 'Bulgaria', 'Canada', 'Chile',
#        'China', 'Croatia', 'Cyprus', 'Czech Republic', 'Egypt', 'England',
#        'France', 'Georgia', 'Germany', 'Greece', 'Hungary', 'India',
#        'Israel', 'Italy', 'Lebanon', 'Luxembourg', 'Macedonia', 'Mexico',
#        'Moldova', 'Morocco', 'New Zealand', 'Peru', 'Portugal', 'Romania',
#        'Serbia', 'Slovakia', 'Slovenia', 'South Africa', 'Spain',
#        'Switzerland', 'Turkey', 'US', 'Ukraine', 'Uruguay'], dtype=object)

# %%
reviews.country=reviews.country.str.lower()
reviews.country
# Out:
# 0            italy
# 1         portugal
# 2               us
# 3               us
# 4               us
#             ...
# 129966     germany
# 129967          us
# 129968      france
# 129969      france
# 129970      france
# Name: country, Length: 129971, dtype: object

# %%
reviews.country=reviews.country.str.strip()
reviews.country
# Out:
# 0            italy
# 1         portugal
# 2               us
# 3               us
# 4               us
#             ...
# 129966     germany
# 129967          us
# 129968      france
# 129969      france
# 129970      france
# Name: country, Length: 129971, dtype: object

# %%
countries=reviews.country.dropna().unique()
countries
# Out:
# array(['italy', 'portugal', 'us', 'spain', 'france', 'germany',
#        'argentina', 'chile', 'australia', 'austria', 'south africa',
#        'new zealand', 'israel', 'hungary', 'greece', 'romania', 'mexico',
#        'canada', 'turkey', 'czech republic', 'slovenia', 'luxembourg',
#        'croatia', 'georgia', 'uruguay', 'england', 'lebanon', 'serbia',
#        'brazil', 'moldova', 'morocco', 'peru', 'india', 'bulgaria',
#        'cyprus', 'armenia', 'switzerland', 'bosnia and herzegovina',
#        'ukraine', 'slovakia', 'macedonia', 'china', 'egypt'], dtype=object)

# %%
countries
# Out:
# array(['italy', 'portugal', 'us', 'spain', 'france', 'germany',
#        'argentina', 'chile', 'australia', 'austria', 'south africa',
#        'new zealand', 'israel', 'hungary', 'greece', 'romania', 'mexico',
#        'canada', 'turkey', 'czech republic', 'slovenia', 'luxembourg',
#        'croatia', 'georgia', 'uruguay', 'england', 'lebanon', 'serbia',
#        'brazil', 'moldova', 'morocco', 'peru', 'india', 'bulgaria',
#        'cyprus', 'armenia', 'switzerland', 'bosnia and herzegovina',
#        'ukraine', 'slovakia', 'macedonia', 'china', 'egypt'], dtype=object)

# %%
countries.sort()
countries
# Out:
# array(['argentina', 'armenia', 'australia', 'austria',
#        'bosnia and herzegovina', 'brazil', 'bulgaria', 'canada', 'chile',
#        'china', 'croatia', 'cyprus', 'czech republic', 'egypt', 'england',
#        'france', 'georgia', 'germany', 'greece', 'hungary', 'india',
#        'israel', 'italy', 'lebanon', 'luxembourg', 'macedonia', 'mexico',
#        'moldova', 'morocco', 'new zealand', 'peru', 'portugal', 'romania',
#        'serbia', 'slovakia', 'slovenia', 'south africa', 'spain',
#        'switzerland', 'turkey', 'ukraine', 'uruguay', 'us'], dtype=object)

# %%
matches = fuzzywuzzy.process.extract("canada", countries, limit=10, scorer=fuzzywuzzy.fuzz.token_sort_ratio)

# take a look at them
matches
# Out:
# [('canada', 100),
#  ('china', 55),
#  ('armenia', 46),
#  ('croatia', 46),
#  ('england', 46),
#  ('romania', 46),
#  ('argentina', 40),
#  ('australia', 40),
#  ('spain', 36),
#  ('new zealand', 35)]

# %%
from ipynb.fs.full.replace_matches_in_columns import replace_matches_in_column

# %%
# use the function we just wrote to replace close matches to "south korea" with "south korea"
replace_matches_in_column(df=reviews, column='country', string_to_match="canada")
# Out:
# All done!

# %%
reviews.country=reviews.country.dropna()

# %%
reviews.country.value_counts()
# Out:
# US                        54504
# France                    22093
# Italy                     19540
# Spain                      6645
# Portugal                   5691
# Chile                      4472
# Argentina                  3800
# Austria                    3345
# Australia                  2329
# Germany                    2165
# New Zealand                1419
# South Africa               1401
# Israel                      505
# Greece                      466
# canada                      258
# Hungary                     146
# Bulgaria                    141
# Romania                     120
# Uruguay                     109
# Turkey                       90
# Slovenia                     87
# Georgia                      86
# England                      74
# Croatia                      73
# Mexico                       70
# Moldova                      59
# Brazil                       52
# Lebanon                      35
# Morocco                      28
# ...

# %%
# !pip install ipython-sql
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 10.8 kB/s eta 0:00:0000:0100:06
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 41.2/41.2 kB 30.0 kB/s eta 0:00:0000:0100:01
# ...
#   Attempting uninstall: sqlalchemy
#     Found existing installation: SQLAlchemy 1.4.39
#     Uninstalling SQLAlchemy-1.4.39:
#       Successfully uninstalled SQLAlchemy-1.4.39
# ...

# %%
# %load_ext sql

# %%
# %sql sqlite://

# %%
# %%sql
# CREATE TABLE EMPLOYEE(firstname varchar(50),lastname varchar(50));
# INSERT INTO EMPLOYEE VALUES('Tom','Mitchell');
# INSERT INTO EMPLOYEE VALUES('Jack','Ryan');
# Out:
#  * sqlite://
# Done.
# 1 rows affected.
# 1 rows affected.
# []

# %%
# %sql select * from EMPLOYEE;
# Out:
#  * sqlite://
# Done.
# [('Tom', 'Mitchell'), ('Jack', 'Ryan')]

# %%
#Specifying the path of the database
# %sql sqlite:////Users/pesseym/Documents/Datasets/SQL_SAFI.sqlite

# %%
# %sql select * from Crops;
# Out:
#    sqlite://
#    sqlite:////Users/pesseym/Documents/Datasets/wine_data.csv
#  * sqlite:////Users/pesseym/Downloads/SQL_SAFI.sqlite
#    sqlite:////Users/pesseym/Downloads/SQL_SAFI_sqlite
#    sqlite:////Users/pesseym/Downloads/SQL_SAFI_sqllite
# Done.
# [(1, 1, 1, 1, 'maize', 1),
#  (1, 2, 1, 1, 'maize', 1),
#  (2, 1, 1, 1, 'maize', 1),
#  (2, 2, 1, 1, 'tomatoes', 1),
#  (2, 3, 1, 1, 'vegetable', 1),
#  (3, 1, 1, 1, 'maize', 1),
#  (4, 1, 1, 1, 'maize', 1),
#  (4, 2, 1, 1, 'maize', 1),
#  (4, 3, 1, 1, 'sorghum', 1),
#  (5, 1, 1, 1, 'maize', 1),
#  (5, 2, 1, 1, 'maize', 1),
#  (6, 1, 1, 1, 'maize', 1),
#  (7, 1, 1, 1, 'maize', 1),
#  (7, 2, 1, 1, 'tomatoes', 1),
#  (7, 3, 1, 1, 'beans', 1),
#  (7, 4, 1, 1, 'vegetable', 1),
#  (8, 1, 1, 1, 'maize', 1),
#  (8, 2, 1, 1, 'maize', 1),
#  (9, 1, 1, 1, 'maize', 1),
#  (9, 2, 1, 1, 'tomatoes', 1),
#  (9, 3, 1, 1, 'vegetable', 1),
#  (10, 1, 1, 1, 'maize', 1),
#  (10, 2, 1, 1, 'tomatoes', 1),
#  (11, 1, 1, 1, 'maize', 1),
# ...

# %%
# %sql select * from Crops where D_curr_crop = "maize" AND ID <= 3;
# Out:
#    sqlite://
#    sqlite:////Users/pesseym/Documents/Datasets/wine_data.csv
#  * sqlite:////Users/pesseym/Downloads/SQL_SAFI.sqlite
#    sqlite:////Users/pesseym/Downloads/SQL_SAFI_sqlite
#    sqlite:////Users/pesseym/Downloads/SQL_SAFI_sqllite
# Done.
# [(1, 1, 1, 1, 'maize', 1),
#  (1, 2, 1, 1, 'maize', 1),
#  (2, 1, 1, 1, 'maize', 1),
#  (3, 1, 1, 1, 'maize', 1)]

# %%
result = %sql select * from Crops where D_curr_crop = "maize" AND ID <= 3;
dataframe = result.DataFrame()
# Out:
#    sqlite://
#    sqlite:////Users/pesseym/Documents/Datasets/wine_data.csv
#  * sqlite:////Users/pesseym/Downloads/SQL_SAFI.sqlite
#    sqlite:////Users/pesseym/Downloads/SQL_SAFI_sqlite
#    sqlite:////Users/pesseym/Downloads/SQL_SAFI_sqllite
# Done.

# %%
dataframe
# Out:
#    Id  plot_Id  crop_Id  D05_times D_curr_crop  D_repeat_times_count
# 0   1        1        1          1       maize                     1
# 1   1        2        1          1       maize                     1
# 2   2        1        1          1       maize                     1
# 3   3        1        1          1       maize                     1

# %%
dataframe.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4 entries, 0 to 3
# Data columns (total 6 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   Id                    4 non-null      int64
#  1   plot_Id               4 non-null      int64
#  2   crop_Id               4 non-null      int64
#  3   D05_times             4 non-null      int64
#  4   D_curr_crop           4 non-null      object
#  5   D_repeat_times_count  4 non-null      int64
# dtypes: int64(5), object(1)
# memory usage: 320.0+ bytes

# %%
# %load_ext sql

# %%
# %sql sqlite://
# %sqlcreate table ANT(firstname varchar(50), lastname varchar(50));

# %%
# %%sql
# insert into ANT values('tom', 'brady');
# insert into ANT values('jim', 'beglin');
# Out:
#  * sqlite://
# 1 rows affected.
# 1 rows affected.
# []

# %%
# %sql select * from ANT
# Out:
#  * sqlite://
# Done.
# [('tom', 'brady'), ('jim', 'beglin')]

# %%
import pandas as pd
df=%sql select * from ANT
df=df.DataFrame()
# Out:
#  * sqlite://
# Done.

# %%
df
# Out:
#   firstname lastname
# 0       tom    brady
# 1       jim   beglin

# %%
from google.cloud import bigquery
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[16], line 1
# ----> 1 from google.cloud import bigquery
#
# ModuleNotFoundError: No module named 'google'

# %%
# %sql sqlite:////Users/pesseym/Documents/Datasets/SQL_SAFI.sqlite

# %%
# %sql select * from Crops
# Out:
#    sqlite://
#  * sqlite:////Users/pesseym/Documents/Datasets/SQL_SAFI.sqlite
# Done.
# [(1, 1, 1, 1, 'maize', 1),
#  (1, 2, 1, 1, 'maize', 1),
#  (2, 1, 1, 1, 'maize', 1),
#  (2, 2, 1, 1, 'tomatoes', 1),
#  (2, 3, 1, 1, 'vegetable', 1),
#  (3, 1, 1, 1, 'maize', 1),
#  (4, 1, 1, 1, 'maize', 1),
#  (4, 2, 1, 1, 'maize', 1),
#  (4, 3, 1, 1, 'sorghum', 1),
#  (5, 1, 1, 1, 'maize', 1),
#  (5, 2, 1, 1, 'maize', 1),
#  (6, 1, 1, 1, 'maize', 1),
#  (7, 1, 1, 1, 'maize', 1),
#  (7, 2, 1, 1, 'tomatoes', 1),
#  (7, 3, 1, 1, 'beans', 1),
#  (7, 4, 1, 1, 'vegetable', 1),
#  (8, 1, 1, 1, 'maize', 1),
#  (8, 2, 1, 1, 'maize', 1),
#  (9, 1, 1, 1, 'maize', 1),
#  (9, 2, 1, 1, 'tomatoes', 1),
#  (9, 3, 1, 1, 'vegetable', 1),
#  (10, 1, 1, 1, 'maize', 1),
#  (10, 2, 1, 1, 'tomatoes', 1),
#  (11, 1, 1, 1, 'maize', 1),
#  (11, 2, 1, 1, 'maize', 1),
#  (12, 1, 1, 0, 'maize', 0),
#  (12, 2, 1, 1, 'tomatoes', 1),
#  (13, 1, 1, 1, 'maize', 1),
#  (13, 2, 1, 1, 'beans', 1),
#  (13, 3, 1, 1, 'vegetable', 1),
# ...

# %%
df=%sql select * from Crops
df=df.DataFrame()
# Out:
#    sqlite://
#  * sqlite:////Users/pesseym/Documents/Datasets/SQL_SAFI.sqlite
# Done.

# %%
df
# Out:
#        Id  plot_Id  crop_Id  D05_times D_curr_crop  D_repeat_times_count
# 0       1        1        1          1       maize                     1
# 1       1        2        1          1       maize                     1
# 2       2        1        1          1       maize                     1
# 3       2        2        1          1    tomatoes                     1
# 4       2        3        1          1   vegetable                     1
# ...   ...      ...      ...        ...         ...                   ...
# 1039  349        1        2          1     sorghum                     1
# 1040  349        2        1          1        rice                     1
# 1041  350        1        1          1       maize                     1
# 1042  350        2        1          1     sorghum                     1
# 1043  350        3        1          1        rice                     1
#
# [1044 rows x 6 columns]

# %%
import google-cloud-sdk
# Out:
#   Cell In[6], line 1
#     import google-cloud-sdk
#                  ^
# SyntaxError: invalid syntax
